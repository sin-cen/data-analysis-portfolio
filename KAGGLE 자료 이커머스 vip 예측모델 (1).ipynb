# %%
import matplotlib.pyplot as plt#   시각화 
import seaborn as sns   #자료 시각화
# 시각화 스타일 설정
sns.set_style('whitegrid')              # 그리드 있는 깔끔한 스타일
plt.rc('font', family='Malgun Gothic')  # 한글 폰트(윈도우: 맑은 고딕)
plt.rc('axes', unicode_minus=False)     # 음수 표시 깨짐 방지
#/////////////////////////////////////////////////////
import matplotlib.pyplot as plt#   시각화 
import seaborn as sns   #자료 시각화

# %%
import pandas as pd

# %%
df=pd.read_csv('archive/E-commerce Customer Behavior - Sheet1.csv')

# %%
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               350 non-null    int64
#  1   Gender                    350 non-null    object
#  2   Age                       350 non-null    int64
#  3   City                      350 non-null    object
#  4   Membership Type           350 non-null    object
#  5   Total Spend               350 non-null    float64
#  6   Items Purchased           350 non-null    int64
#  7   Average Rating            350 non-null    float64
#  8   Discount Applied          350 non-null    bool
#  9   Days Since Last Purchase  350 non-null    int64
#  10  Satisfaction Level        348 non-null    object
# dtypes: bool(1), float64(2), int64(4), object(4)
# memory usage: 27.8+ KB

# %%
df['Age'].value_counts()
# Out:
# Age
# 30    48
# 32    33
# 43    25
# 27    25
# 31    25
# 35    25
# 36    25
# 34    24
# 37    24
# 41    24
# 28    24
# 29    11
# 33    10
# 42     9
# 26     9
# 38     9
# Name: count, dtype: int64

# %%
df.loc[(df['Age']>=20) & (df['Age']<30) ,'age_group']='20대'
# Out:
# C:\Users\SHIN\AppData\Local\Temp\ipykernel_11972\3344312933.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '20대' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[(df['Age']>=20) & (df['Age']<30) ,'age_group']='20대'

# %%
df.loc[(df['Age']>=30) & (df['Age']<40) ,'age_group']='30대'

# %%
df.loc[(df['Age']>=40) & (df['Age']<50) ,'age_group']='40대'

# %%
df.loc[(df['Age']>=50) & (df['Age']<60) ,'age_group']='50대'

# %%
df['age_group'].value_counts()
# Out:
# age_group
# 30대    223
# 20대     69
# 40대     58
# Name: count, dtype: int64

# %%
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'City', 'Membership Type',
#        'Total Spend', 'Items Purchased', 'Average Rating', 'Discount Applied',
#        'Days Since Last Purchase', 'Satisfaction Level', 'age_group'],
#       dtype='object')

# %%
df['Membership Type'].value_counts()
# Out:
# Membership Type
# Gold      117
# Silver    117
# Bronze    116
# Name: count, dtype: int64

# %%
df['Total Spend'].describe()
# Out:
# count     350.000000
# mean      845.381714
# std       362.058695
# min       410.800000
# 25%       502.000000
# 50%       775.200000
# 75%      1160.600000
# max      1520.100000
# Name: Total Spend, dtype: float64

# %%
df['vip_yn']=0

# %%
df.loc[df['Total Spend']>1160,'vip_yn']=1

# %%
df['vip_yn'].value_counts()
# Out:
# vip_yn
# 0    254
# 1     96
# Name: count, dtype: int64

# %%
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
import pandas as pd
# 데이터 처리
import pandas as pd

# StringIO (CSV를 문자열로 처리)
from io import StringIO

# DB (SQLite)
import sqlite3

# =========================
# 1) import
# =========================
import pandas as pd
from io import StringIO
from sqlalchemy import create_engine, text

# %%
## mariadb 연결 정보
USER='root'
PASSWORD='1234'
HOST='localhost'
PORT=3306
DB='poto1'    

engine=create_engine(
    f'mysql+pymysql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB}?charset=utf8mb4'
)

# %%
df.to_sql('data_d',con=engine,if_exists='replace',index=False)
# Out:
# 350

# %%
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'City', 'Membership Type',
#        'Total Spend', 'Items Purchased', 'Average Rating', 'Discount Applied',
#        'Days Since Last Purchase', 'Satisfaction Level', 'age_group',
#        'vip_yn'],
#       dtype='object')

# %%
sql='''select d.age_group,d.Gender,sum(d.`Total Spend`)as sum_spend
from data_d d
group by d.age_group,d.Gender
order by sum_spend desc;'''

# %%
sql2='''select d.`Membership Type`,avg(d.`Total Spend`)as avg_spend,avg(d.`Items Purchased`)
from data_d d
group by d.`Membership Type`
order by avg_spend desc;
'''

# %%
sql3='''select d.`Customer ID`,d.`Membership Type`,d.`Satisfaction Level`,d.`Days Since Last Purchase`
from data_d d
where d.`Satisfaction Level`='Unsatisfied' and d.`Days Since Last Purchase`>= 60'''

# %%
df1=pd.read_sql(sql,engine)

# %%
df2=pd.read_sql(sql2,engine)

# %%
df3=pd.read_sql(sql3,engine)

# %%
print(df1)
print('----------')
print(df2)
print('-----------')
print(df3)
# Out:
#   age_group  Gender  sum_spend
# 0       30대    Male   100583.5
# 1       30대  Female    92326.2
# 2       20대    Male    72130.1
# 3       40대  Female    28993.2
# 4       20대  Female     1850.6
# ----------
#   Membership Type    avg_spend  avg(d.`Items Purchased`)
# 0            Gold  1311.144444                   17.6154
# 1          Silver   748.432479                   11.6581
# 2          Bronze   473.388793                    8.4914
# -----------
#    Customer ID Membership Type Satisfaction Level  Days Since Last Purchase
# 0          404          Silver        Unsatisfied                        60
# 1          416          Silver        Unsatisfied                        61
# 2          428          Silver        Unsatisfied                        62
# 3          440          Silver        Unsatisfied                        63

# %%
df1
# Out:
#   age_group  Gender  sum_spend
# 0       30대    Male   100583.5
# 1       30대  Female    92326.2
# 2       20대    Male    72130.1
# 3       40대  Female    28993.2
# 4       20대  Female     1850.6

# %%
sns.barplot(df1,x='age_group',y='sum_spend')
plt.title('나이별 소비그래프')
# Out:
# Text(0.5, 1.0, '나이별 소비그래프')

# %%
df2
# Out:
#   Membership Type    avg_spend  avg(d.`Items Purchased`)
# 0            Gold  1311.144444                   17.6154
# 1          Silver   748.432479                   11.6581
# 2          Bronze   473.388793                    8.4914

# %%
sns.barplot(df2,x='Membership Type',y='avg_spend')
plt.title('맴버쉽별 매출 그래프')
# Out:
# Text(0.5, 1.0, '맴버쉽별 매출 그래프')

# %%
sns.barplot(df2,x='Membership Type',y='avg(d.`Items Purchased`)')
plt.title('맴버쉽별 구매전환율')
# Out:
# Text(0.5, 1.0, '맴버쉽별 구매전환율')

# %%
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'City', 'Membership Type',
#        'Total Spend', 'Items Purchased', 'Average Rating', 'Discount Applied',
#        'Days Since Last Purchase', 'Satisfaction Level', 'age_group',
#        'vip_yn'],
#       dtype='object')

# %%
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
df[['Age','Average Rating','Discount Applied','Days Since Last Purchase']].corr()
# Out:
#                                Age  Average Rating  Discount Applied  \
# Age                       1.000000       -0.722277          0.056979
# Average Rating           -0.722277        1.000000         -0.068507
# Discount Applied          0.056979       -0.068507          1.000000
# Days Since Last Purchase  0.168763       -0.430757          0.759543
#
#                           Days Since Last Purchase
# Age                                       0.168763
# Average Rating                           -0.430757
# Discount Applied                          0.759543
# Days Since Last Purchase                  1.000000

# %%
X=df[['Age','Average Rating','Discount Applied','Days Since Last Purchase']]
y=df['vip_yn']

# %%
df['vip_yn'].value_counts()
# Out:
# vip_yn
# 0    254
# 1     96
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(max_iter=1000)
model.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9619047619047619
#
# Confusion Matrix
#  [[73  3]
#  [ 1 28]]
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97        76
#            1       0.90      0.97      0.93        29
#
#     accuracy                           0.96       105
#    macro avg       0.94      0.96      0.95       105
# weighted avg       0.96      0.96      0.96       105

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.9619047619047619

# %%
from sklearn.metrics import roc_auc_score

y_prob = model.predict_proba(X_test_scaled)[:,1]
roc_auc_score(y_test, y_prob)
# Out:
# 0.9977313974591652

# %%
pd.Series(model.coef_[0], index=X.columns).sort_values(ascending=False)
# Out:
# Average Rating              2.568659
# Discount Applied            0.764210
# Age                        -1.917517
# Days Since Last Purchase   -2.046063
# dtype: float64

# %%
#Average Rating (+)
#→ 평점이 높을수록 VIP일 확률 ↑

#Discount Applied (+)
#→ 할인 경험 고객이 VIP일 가능성 ↑

#Age (−)
#→ 나이가 많을수록 VIP일 확률 ↓

#Days Since Last Purchase (−)
#→ 최근에 구매했을수록 VIP일 확률 ↑
